# %%
import json
from readingdb.api import API
from readingdb.endpoints import DYNAMO_ENDPOINT

# %%
rid = '19284b86-d3ea-11eb-92f5-0242517c8716'
# rid = 'c3bea28e-d33b-11eb-8f22-0242aca516e1'
# rid = "5f7b1278-d3de-11eb-92f5-0242517c8716" DONE

# %%
api = API(DYNAMO_ENDPOINT)

# %%
rs = api.all_route_readings(rid)
# Out:
# response size: 9774894

# %%
rs = [r for r in rs if r['Type'] == 'PredictionReading' and len(r['Reading']['Entities']) > 0]

# %%
with open(f'/home/lewington/backup/{rid}', 'w') as f:
    json.dump(rs, f)

# %%
def faults(reading):
    labels = []
    for e in reading['Reading']['Entities']:
        if e['Present']:
            labels.append(e['Name'])
    return labels

# %%
count = 0
for r in rs:
    labels = faults(r)   
    if 'D100' in labels and 'D60' in labels:
        if len(labels) == 2:
            r['Reading']['Entities'] = [{
                'Name': 'D1001',
                'Confidence': 1,
                'Present': True,
                'Severity': 0
            }]
        elif len(labels) == 3:
            if 'D203' in labels:
                r['Reading']['Entities'] = [
                    {
                        'Name': 'D1001',
                        'Confidence': 1,
                        'Present': True,
                        'Severity': 0
                    },
                    {
                        'Name': 'D203',
                        'Confidence': 1,
                        'Present': True,
                        'Severity': 0
                    }
                ]
    if 'D100' in labels:
        if len(labels) == 1:
            r['Reading']['Entities'] = [{
                'Name': 'D1001',
                'Confidence': 1,
                'Present': True,
                'Severity': 0
            }]
        else:
            new_entities = []
            
            for e in r['Reading']['Entities']:
                if e['Name'] != 'D100':
                    new_entities.append(e)
            r['Reading']['Entities'] = new_entities

# %%
count = 0
for r in rs:
    labels = faults(r)   
    print(labels)
# Out:
# ['D110']
# ['D110']
# ['D110']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D05']
# ['D05']
# ['D05', 'D203']
# ['D203']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ['D1001']
# ...

# %%
api.save_predictions(rs, rid, 'a2eb9df8-54ab-419f-9a97-ff69513d7809')
# Out:
# response size: 9774674
# uploading entry 0 of 3910
# uploading entry 10 of 3910
# uploading entry 20 of 3910
# uploading entry 30 of 3910
# uploading entry 40 of 3910
# uploading entry 50 of 3910
# uploading entry 60 of 3910
# uploading entry 70 of 3910
# uploading entry 80 of 3910
# uploading entry 90 of 3910
# uploading entry 100 of 3910
# uploading entry 110 of 3910
# uploading entry 120 of 3910
# uploading entry 130 of 3910
# uploading entry 140 of 3910
# uploading entry 150 of 3910
# uploading entry 160 of 3910
# uploading entry 170 of 3910
# uploading entry 180 of 3910
# uploading entry 190 of 3910
# uploading entry 200 of 3910
# uploading entry 210 of 3910
# uploading entry 220 of 3910
# uploading entry 230 of 3910
# uploading entry 240 of 3910
# uploading entry 250 of 3910
# uploading entry 260 of 3910
# uploading entry 270 of 3910
# uploading entry 280 of 3910
# uploading entry 290 of 3910
# uploading entry 300 of 3910
# uploading entry 310 of 3910
# ...
