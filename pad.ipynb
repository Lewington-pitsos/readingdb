# %%
import sys
import json
from readingdb.endpoints import DYNAMO_ENDPOINT
from readingdb.api import API

api = API(DYNAMO_ENDPOINT)

rs = api.all_route_readings(
    '5f7b1278-d3de-11eb-92f5-0242517c8716'
)

# %%
print(len(rs))
jstr = json.dumps(rs)
sys.getsizeof(jstr)
# Out:
# 3845
# 2887352

# %%
print(len(rs))
jstr = json.dumps(rs)
sys.getsizeof(jstr)
# Out:
# 4064
# 2985216

# %%
print(len(rs))
jstr = json.dumps(rs)
sys.getsizeof(jstr)
# Out:
# 4019
# 2852911

# %%
print(len(rs))
jstr = json.dumps(rs)
sys.getsizeof(jstr)
# Out:
# 4299
# 2901610

# %%
sys.getsizeof(jstr)
# Out:
# 2887328

# %%
rs[0]
# Out:
# {'Timestamp': 1624243133265,
#  'ReadingID': 'dfb5a3d5-d47b-11eb-af1d-0242247ac2c5',
#  'RouteID': 'dfb5a3d4-d47b-11eb-af1d-0242247ac2c5',
#  'AnnotationTimestamp': 1624488702626,
#  'Reading': {'Latitude': -37.62822318596598,
#   'Longitude': 144.64447384477015,
#   'S3Uri': {'Bucket': 'mobileappsessions172800-main',
#    'Key': 'route_1624242817519/img_1624243133265-300.jpg'},
#   'Entities': [],
#   'PresignedURL': 'https://mobileappsessions172800-main.s3.amazonaws.com/route_1624242817519/img_1624243133265-300.jpg?AWSAccessKeyId=AKIA52XQLVT4SJH3IWTS&Signature=15mBeuaG9Epfyn3lsqHM%2FJ1sqik%3D&Expires=1624763730'},
#  'Type': 'PredictionReading',
#  'AnnotatorID': '3f01d5ec-c80b-11eb-acfa-02428ee80691'}

# %%
for r in rs:
    del r['Reading']['PresignedURL']

# %%
jstr2 = json.dumps(rs)

# %%
jstr
# Out:
# '[{"Timestamp": 1624243133265, "ReadingID": "dfb5a3d5-d47b-11eb-af1d-0242247ac2c5", "RouteID": "dfb5a3d4-d47b-11eb-af1d-0242247ac2c5", "AnnotationTimestamp": 1624488702626, "Reading": {"Latitude": -37.62822318596598, "Longitude": 144.64447384477015, "S3Uri": {"Bucket": "mobileappsessions172800-main", "Key": "route_1624242817519/img_1624243133265-300.jpg"}, "Entities": [], "PresignedURL": "https://mobileappsessions172800-main.s3.amazonaws.com/route_1624242817519/img_1624243133265-300.jpg?AWSAccessKeyId=AKIA52XQLVT4SJH3IWTS&Signature=15mBeuaG9Epfyn3lsqHM%2FJ1sqik%3D&Expires=1624763730"}, "Type": "PredictionReading", "AnnotatorID": "3f01d5ec-c80b-11eb-acfa-02428ee80691"}, {"Timestamp": 1624243134807, "ReadingID": "dfb5a3d6-d47b-11eb-af1d-0242247ac2c5", "RouteID": "dfb5a3d4-d47b-11eb-af1d-0242247ac2c5", "AnnotationTimestamp": 1624488702626, "Reading": {"Latitude": -37.62822874588026, "Longitude": 144.6440765702655, "S3Uri": {"Bucket": "mobileappsessions172800-main", "Key": "route_1624242817519/img_1624243134807-308.jpg"}, "Entities": [], "PresignedURL": "https://mobileappsessions172800-main.s3.amazonaws.com/route_1624242817519/img_1624243134807-308.jpg?AWSAccessKeyId=AKIA52XQLVT4SJH3IWTS&Signature=%2BhSh1wYEd1RskmZl3a4QGMWkcAU%3