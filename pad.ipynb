# %%
import json
from readingdb.api import API
from readingdb.geolocator import Geolocator
from readingdb.endpoints import DYNAMO_ENDPOINT

# %%
rid = 'c3bea28e-d33b-11eb-8f22-0242aca516e1'

# %%
api = API(DYNAMO_ENDPOINT)

# %%
rs = api.all_route_readings(rid)
# Out:
# response size: 10381580

# %%
rs = sorted(rs, key=lambda r: r['Timestamp'])

# %%
g = Geolocator(overlap=30)

# %%
qs = g.geolocate(rs)

# %%
from collections import defaultdict

# %%
placeids = []

pidcnts = defaultdict(lambda: 0)
for q in qs:
    pid = q['Reading']['PlaceID']
    if not pid in placeids:
        placeids.append(pid)
    
    pidcnts[pid] += 1

# %%
pidcnts
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'ChIJXXmBsdJf1moRlaC9EIJ1buM': 50,
#              'ChIJCSoqrNJf1moRMA51IfDyiOw': 40,
#              'ChIJCSoqrNJf1moR4v1bxa34r5I': 14,
#              'ChIJI30UqtJf1moRre0OQUZFX38': 22,
#              'ChIJvUqGUs1f1moRNTYr02935-Q': 125,
#              'ChIJkVNm0zJe1moRe01T8hzG-0Q': 228,
#              'ChIJkVNm0zJe1moRE923W0VqK8s': 74,
#              'ChIJq9EYNDNe1moRCOiIrP53VVc': 111,
#              'ChIJNdM4TjNe1moRDQ4S8uJBj8s': 84,
#              'ChIJccslqDRe1moRycHlRmXIgjs': 52,
#              'ChIJZ0ILujRe1moRd4BVAlc0PlM': 103,
#              'ChIJZ0ILujRe1moRRnO9juLa2LE': 13,
#              'ChIJ54Em2zRe1moRMKzq63RWBBM': 86,
#              'ChIJDy_1IzVe1moR8YTq63RWBBM': 83,
#              'ChIJHzf2QDVe1moR3oPNuRrY2b4': 48,
#              'ChIJHzf2QDVe1moReJRUyWxPyVU': 35,
#              'ChIJHXP4QDVe1moRyiHP-6iUq7I': 2,
#              'ChIJTznuXTVe1moR4Tzq63RWBBM': 48,
#              'ChIJPQy5mEpe1moRcSzq63RWBBM': 77,
# ...

# %%
len(qs)
# Out:
# 8309

# %%
len(placeids)
# Out:
# 198

# %%
data = [q for q in qs if q['Reading']['PlaceID'] == 'ChIJgyh2q0Ff1moR6nmtRZOH3sw']
with open(f'/home/lewington/code/polylines/data.json', 'w') as f:
    json.dump(data, f)

# %%
img_readings = qs[4925:4995]
pos_readings = [qs[4924], qs[4996]]
sd = g.interpolated(pos_readings, img_readings)

# %%
qs[4925:4995] = sd

# %%
with open(f'/home/lewington/code/polylines/data.json', 'w') as f:
    json.dump(qs, f)

# %%
with open(f'/home/lewington/code/polylines/backup.json', 'w') as f:
    json.dump(qs, f)

# %%
saved = api.save_predictions(qs, 'c3bea28e-d33b-11eb-8f22-0242aca516e1', '2f11b71a-cecf-40b8-ab6b-8c73e4254b26')
# Out:
# response size: 51
# uploading entry 0 of 8281
# uploading entry 10 of 8281
# uploading entry 20 of 8281
# uploading entry 30 of 8281
# uploading entry 40 of 8281
# uploading entry 50 of 8281
# uploading entry 60 of 8281
# uploading entry 70 of 8281
# uploading entry 80 of 8281
# uploading entry 90 of 8281
# uploading entry 100 of 8281
# uploading entry 110 of 8281
# uploading entry 120 of 8281
# uploading entry 130 of 8281
# uploading entry 140 of 8281
# uploading entry 150 of 8281
# uploading entry 160 of 8281
# uploading entry 170 of 8281
# uploading entry 180 of 8281
# uploading entry 190 of 8281
# uploading entry 200 of 8281
# uploading entry 210 of 8281
# uploading entry 220 of 8281
# uploading entry 230 of 8281
# uploading entry 240 of 8281
# uploading entry 250 of 8281
# uploading entry 260 of 8281
# uploading entry 270 of 8281
# uploading entry 280 of 8281
# uploading entry 290 of 8281
# uploading entry 300 of 8281
# uploading entry 310 of 8281
# uploading entry 320 of 8281
# ...

# %%
api.delete_reading_items('c3bea28e-d33b-11eb-8f22-0242aca516e1', [r['ReadingID'] for r in remaining])

# %%
remaining = api.all_route_readings(rid)
# Out:
# response size: 51

# %%
with open('/home/lewington/backup/c3bea28e-d33b-11eb-8f22-0242aca516e1', 'r') as f:
    rs = json.load(f)

# %%
rs = sorted(rs, key=lambda r: r["Timestamp"])

# %%
with open(f'/home/lewington/code/polylines/data.json', 'w') as f:
    json.dump(rs, f)

# %%
start = 4950
end = 5087

# %%
with open(f'/home/lewington/code/polylines/data.json', 'w') as f:
    json.dump(rs[start:end], f)

# %%
img_readings = rs[start:end]
final = copy.deepcopy(rs[end+1])

final['Reading']['Latitude'] = -37.72958742267097
final['Reading']['Longitude'] = 144.8151431338034

pos_readings = [rs[start-1], final]
sd = g.interpolated(pos_readings, img_readings)

# %%
cnt = 0
for r in rs:
    for s in sd:
        if r['Reading']['S3Uri']['Key'] == s['Reading']['S3Uri']['Key']:
            r['Reading']['Latitude'] = s['Reading']['Latitude'] 
            r['Reading']['Longitude'] = s['Reading']['Longitude'] 
            cnt += 1
            break
print(cnt)
# Out:
# 138

# %%
start = 5087
end = 5130

# %%
with open(f'/home/lewington/code/polylines/data.json', 'w') as f:
    json.dump(rs[start:end], f)

# %%
img_readings = rs[start:end]

pos_readings = [rs[start-1], rs[end+1]]
sd = g.interpolated(pos_readings, img_readings)

# %%
cnt = 0
for r in rs:
    for s in sd:
        if r['Reading']['S3Uri']['Key'] == s['Reading']['S3Uri']['Key']:
            r['Reading']['Latitude'] = s['Reading']['Latitude'] 
            r['Reading']['Longitude'] = s['Reading']['Longitude'] 
            cnt += 1
            break
print(cnt)
# Out:
# 44

# %%
with open(f'/home/lewington/code/polylines/data.json', 'w') as f:
    json.dump(rs, f)

# %%
saved = api.save_predictions(rs, 'c3bea28e-d33b-11eb-8f22-0242aca516e1', '2f11b71a-cecf-40b8-ab6b-8c73e4254b26')
# Out:
# response size: 51
# uploading entry 0 of 8309
# uploading entry 10 of 8309
# uploading entry 20 of 8309
# uploading entry 30 of 8309
# uploading entry 40 of 8309
# uploading entry 50 of 8309
# uploading entry 60 of 8309
# uploading entry 70 of 8309
# uploading entry 80 of 8309
# uploading entry 90 of 8309
# uploading entry 100 of 8309
# uploading entry 110 of 8309
# uploading entry 120 of 8309
# uploading entry 130 of 8309
# uploading entry 140 of 8309
# uploading entry 150 of 8309
# uploading entry 160 of 8309
# uploading entry 170 of 8309
# uploading entry 180 of 8309
# uploading entry 190 of 8309
# uploading entry 200 of 8309
# uploading entry 210 of 8309
# uploading entry 220 of 8309
# uploading entry 230 of 8309
# uploading entry 240 of 8309
# uploading entry 250 of 8309
# uploading entry 260 of 8309
# uploading entry 270 of 8309
# uploading entry 280 of 8309
# uploading entry 290 of 8309
# uploading entry 300 of 8309
# uploading entry 310 of 8309
# uploading entry 320 of 8309
# ...
