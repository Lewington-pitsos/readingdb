# %%
import boto3
from readingdb.api import API
from readingdb.endpoints import DYNAMO_ENDPOINT
import sys

# %%
api = API(DYNAMO_ENDPOINT)

# %%
w = api.all_route_readings('57a98e88-c91d-11eb-8b05-024221cba9cc')

# %%
all_ids = set()

for r in rs:
    all_ids.add(r["AnnotatorID"])

# %%
all_ids
# Out:
# {'3f01d5ec-c80b-11eb-acfa-02428ee80691',
#  '99bf4519-85d9-4726-9471-4c91a7677925'}

# %%
rs, key = api.filtered_paginated_readings(
    '57a98e88-c91d-11eb-8b05-024221cba9cc',
    ['99bf4519-85d9-4726-9471-4c91a7677925'],
)

# %%
len(rs)
# Out:
# 538

# %%
key
# Out:
# {'ReadingID': 'f3f8da9d-c91d-11eb-8b05-024221cba9cc',
#  'RouteID': '57a98e88-c91d-11eb-8b05-024221cba9cc'}

# %%
rs = []
for r in w:
    if r["AnnotatorID"] == '3f01d5ec-c80b-11eb-acfa-02428ee80691':
        rs.append(r)

# %%
rs
# Out:
# [{'Timestamp': 1620814386932,
#   'ReadingID': 'f3f8d884-c91d-11eb-8b05-024221cba9cc',
#   'RouteID': '57a98e88-c91d-11eb-8b05-024221cba9cc',
#   'AnnotationTimestamp': 1623133800,
#   'Reading': {'Entities': [{'Severity': 1.0,
#      'Present': True,
#      'Confidence': 1.0,
#      'Name': 'D00'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D05'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D10'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D20'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D40'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D44'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D60'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D100'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D110'},
#     {'Severity': 0.0, 'Present': False, 'Confidence': 0.0, 'Name': 'D120'},
# ...

# %%
client = boto3.client('cognito-idp')

# %%
auth_resp = client.initiate_auth(
    AuthFlow='USER_PASSWORD_AUTH',
    AuthParameters={
        'USERNAME': 'fdsadmin',
        'PASSWORD': '3oH2xJLw96bTJM'
    },
    ClientId='4uqhqsooe43ebtq0obvn0lm7ui'
)

# %%
x = client.get_user(AccessToken='eyJraWQiOiI0QXl3TjdidExEWm1RWFBEdVpxZ3JRTVk2MkVheXc0ZlN6eXBNcFI2bDh3PSIsImFsZyI6IlJTMjU2In0.....D9pv2VSn6YgEMYDlUfQB6azJnfI3xX6DGrPYAmGm_X5Y_YVauTs6xOIGZvp9DJlXJZcANGTFYuBfCuagbaXYtMifr1a-_C2rfEQdweJGfBi1afKdbz7SuG9zObdebgTP3xEBTaAFZIptBC_92RjxNynr6OCMlE6YaGWmexfdItUHZMe5iPuIyqSVkKtC-DrFbE2OQxbwmI2JMJ6p0yY9KO_aH4u98ZJJ_okDA5RZ5xnDY_KcojMENuk7Zhg2gV5FzBS0usu41rhpQWET8h5HdNMwXNMOn09JErrcLhvxClgZm3n5hBlrNAQBZOX-ZGqgRKD72LoQhlBpL598ZyDDdQ')

# %%
import time

# %%
time.time()
# Out:
# 1623492286.6260593

# %%
x
# Out:
# {'Username': 'fdsadmin',
#  'UserAttributes': [{'Name': 'sub',
#    'Value': '99bf4519-85d9-4726-9471-4c91a7677925'},
#   {'Name': 'email_verified', 'Value': 'true'},
#   {'Name': 'phone_number_verified', 'Value': 'true'},
#   {'Name': 'phone_number', 'Value': '+610491158824'},
#   {'Name': 'email', 'Value': 'lewingtonpitsos@frontlinedatasystems.com'}],
#  'ResponseMetadata': {'RequestId': '51e95273-2ab7-4595-8202-3ed7c2452fe9',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Sat, 12 Jun 2021 08:44:24 GMT',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '309',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '51e95273-2ab7-4595-8202-3ed7c2452fe9'},
#   'RetryAttempts': 0}}

# %%
q = 'eyJraWQiOiI0QXl3TjdidExEWm1RWFBEdVpxZ3JRTVk2MkVheXc0ZlN6eXBNcFI2bDh3PSIsImFsZyI6IlJTMjU2In0.....D9pv2VSn6YgEMYDlUfQB6azJnfI3xX6DGrPYAmGm_X5Y_YVauTs6xOIGZvp9DJlXJZcANGTFYuBfCuagbaXYtMifr1a-_C2rfEQdweJGfBi1afKdbz7SuG9zObdebgTP3xEBTaAFZIptBC_92RjxNynr6OCMlE6YaGWmexfdItUHZMe5iPuIyqSVkKtC-DrFbE2OQxbwmI2JMJ6p0yY9KO_aH4u98ZJJ_okDA5RZ5xnDY_KcojMENuk7Zhg2gV5FzBS0usu41rhpQWET8h5HdNMwXNMOn09JErrcLhvxClgZm3n5hBlrNAQBZOX-ZGqgRKD72LoQhlBpL598ZyDDdQ'

# %%
auth_resp
# Out:
# {'ChallengeParameters': {},
#  'AuthenticationResult': {'AccessToken': 'eyJraWQiOiI0QXl3TjdidExEWm1RWFBEdVpxZ3JRTVk2MkVheXc0ZlN6eXBNcFI2bDh3PSIsImFsZyI6IlJTMjU2In0.....D9pv2VSn6YgEMYDlUfQB6azJnfI3xX6DGrPYAmGm_X5Y_YVauTs6xOIGZvp9DJlXJZcANGTFYuBfCuagbaXYtMifr1a-_C2rfEQdweJGfBi1afKdbz7SuG9zObdebgTP3xEBTaAFZIptBC_92RjxNynr6OCMlE6YaGWmexfdItUHZMe5iPuIyqSVkKtC-DrFbE2OQxbwmI2JMJ6p0yY9KO_aH4u98ZJJ_okDA5RZ5xnDY_KcojMENuk7Zhg2gV5FzBS0usu41rhpQWET8h5HdNMwXNMOn09JErrcLhvxClgZm3n5hBlrNAQBZOX-ZGqgRKD72LoQhlBpL598ZyDDdQ',
#   'ExpiresIn': 3600,
#   'TokenType': 'Bearer',
# ...
